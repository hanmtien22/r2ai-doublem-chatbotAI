# %%
from pathlib import Path
from collections import Counter
from path import FINANCIAL_STATEMENTS

files = list(FINANCIAL_STATEMENTS.rglob("*_extracted.txt"))
print(len(files))
# Out:
# 1973

# %%
for path in files[:5]:
    print("=" * 80)
    print(path)

    text = path.read_text(encoding="utf-8", errors="replace")
    print(text[:3000])
# Out:
# ...
# /home/duymanh/code/project/r2ai-doublem-chatbotAI/data/financial_statements/HUT/2018/HUT_financial_statements_2018_consolidated/HUT_financial_statements_2018_consolidated_extracted.txt
# ===== PAGE 1 =====
# CÔNG TY CỔ PHẦN TASCO
#
# BÁO CÁO TÀI CHÍNH HỢP NHẤT ĐÃ ĐƯỢC KIỂM TOÁN
#
# Cho năm tài chính kết thúc ngày 31 tháng 12 năm 2018
#
# Hà Nội - Tháng 03 năm 2019
#
# ===== PAGE 2 =====
# CÔNG TY CỔ PHẦN TASCO
#
# MỤC LỤC
#
# <table><tr><td>NÔI DUNG</td><td>Trang</td></tr><tr><td>BÁO CÁO CỦA BAN TỔNG GIÁM ĐỐC</td><td>2 - 3</td></tr><tr><td>BÁO CÁO KIỂM TOÁN ĐỘC LẬP</td><td>4 - 5</td></tr><tr><td>BÁO CÁO TÀI CHÍNH HỢP NHẤT ĐÃ ĐƯỢC KIỂM TOÁN</td><td></td></tr><tr><td>Bàng Cân đối kế toán hợp nhất</td><td>6 - 7</td></tr><tr><td>Báo cáo Kết quả hoạt động kinh doanh hợp nhất</td><td>8</td></tr><tr><td>Báo cáo Lưu chuyển tiền tệ hợp nhất</td><td>9</td></tr><tr><td>Bàn thuyết minh Báo cáo tài chính hợp nhất</td><td>10 - 49</td></tr></table>
#
# 1
#
# ===== PAGE 3 =====
# ...
